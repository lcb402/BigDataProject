# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %% [markdown]
# # Day/night coll per borough

# %%
d_n = pd.read_csv("rush_hour.csv", sep='\t', header = None)
print d_n.shape[0]
print d_n
# Out:
# 162961
# night                    0       1
# borough
# BRONX          1072.928571   615.0
# BROOKLYN       2618.142857  1403.7
# MANHATTAN      2084.071429  1322.7
# QUEENS         2195.857143  1162.8
# STATEN ISLAND   337.142857   160.5

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

N = 5
ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, d_n[0], width, color='y')

rects2 = ax.bar(ind + width, d_n[1], width, color='black')

# add some text for labels, title and axes ticks
ax.set_ylabel('Number of Collisions')
ax.set_title('Number of Collisions Based on Day/Night')
ax.set_xticks(ind + width)
ax.set_xticklabels(('Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island'))
#ax.set_ylim([0,8500])
ax.legend((rects1[0], rects2[0]), ('Day', 'Night'))


def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %% [markdown]
# # Weekend

# %%
d_n = pd.read_csv("weekend.csv", sep='\t', header = None)
print d_n.shape[0]
print d_n
# Out:
# 162961
# weekend             0       1
# borough
# BRONX          3097.6  2841.5
# BROOKLYN       7353.4  6962.0
# MANHATTAN      6367.4  5283.5
# QUEENS         6173.6  5751.0
# STATEN ISLAND   938.2   817.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

N = 5
ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, d_n[0], width, color='grey')

rects2 = ax.bar(ind + width, d_n[1], width, color='m')

# add some text for labels, title and axes ticks
ax.set_ylabel('Number of Collisions')
ax.set_ylim([0,8500])
ax.set_title('Number of Collisions Based on Weekdays vs. Saturday or Sunday')
ax.set_xticks(ind + width)
ax.set_xticklabels(('Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island'))

ax.legend((rects1[0], rects2[0]), ('Mon - Fr', 'Saturday-Sunday'))


def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %% [markdown]
# # Rush hour

# %%
d_n = pd.read_csv("rush_hour.csv", sep='\t', header = None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

N = 5
ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, d_n[0], width, color='g')

rects2 = ax.bar(ind + width, d_n[1], width, color='r')

# add some text for labels, title and axes ticks
ax.set_ylabel('Number of Collisions')
ax.set_ylim([0,5000])
ax.set_title('Number of Collisions Based on Normal Hours/Rush Hour')
ax.set_xticks(ind + width)
ax.set_xticklabels(('Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island'))

ax.legend((rects1[0], rects2[0]), ('Normal Hours', 'Rush Hour'))


def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %% [markdown]
# # Visibility

# %%
d_n = pd.read_csv("visibility.csv", sep='\t', header = None)
print d_n.shape[0]
print d_n
# Out:
# 162961
# bad_visib             0         1
# borough
# BRONX          0.129933  0.129171
# BROOKLYN       0.310883  0.318251
# MANHATTAN      0.260677  0.241405
# QUEENS         0.259740  0.270475
# STATEN ISLAND  0.038766  0.040698

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

N = 5
ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, d_n[0], width, color='y')

rects2 = ax.bar(ind + width, d_n[1], width, color='b')

# add some text for labels, title and axes ticks
ax.set_ylabel('(Normalized) Number of Collisions')
ax.set_title('(Normalized) Number of Collisions Based On Visibility')
ax.set_xticks(ind + width)
ax.set_xticklabels(('Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island'))

ax.legend((rects1[0], rects2[0]), ('Good Visibility', 'Bad Visibility'))



plt.show()

# %% [markdown]
# # Precipitation

# %%
d_n = pd.read_csv("precipitation.csv", sep='\t', header = None)
print d_n.shape[0]
print d_n
# Out:
# 162961
# precip                0         1
# borough
# BRONX          0.126303  0.131309
# BROOKLYN       0.313179  0.310245
# MANHATTAN      0.259569  0.260457
# QUEENS         0.262697  0.258960
# STATEN ISLAND  0.038252  0.039029

# %%
N = 5
ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, d_n[0], width, color='y')

rects2 = ax.bar(ind + width, d_n[1], width, color='grey')

# add some text for labels, title and axes ticks
ax.set_ylabel('(Normalized) Number of Collisions')
ax.set_title('(Normalized) Number of Collisions Based on Precipitation')
ax.set_xticks(ind + width)
ax.set_xticklabels(('Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island'))

ax.legend((rects1[0], rects2[0]), ('No Precipitation', 'Precipitation'))



plt.show()
